# %% [markdown]
# <a href="https://colab.research.google.com/github/Vignesh141099/EDA-Visuals-assignment/blob/main/EDA_Visuals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python for Data Science & Analysis
# ## Notes 3.1, Exploratory Data Analysis & Visualization

# %% [markdown]
# ## Objectives
# * write a program which uses seaborn to:
#     * show univariate plots (eg., distplot)
#     * show multivariate plots (eg., scatterplot)
#     * EXTRA: customize plots

# %% [markdown]
# # Part 3: Visualization

# %% [markdown]
# ## How do I use pandas to plot?

# %% [markdown]
# Pandas has a `.plot` which you configure using its arguments (eg., `kind=hist`), this however *just uses* seaborn.

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2a166136-d0d0-4493-886b-2dff9f9c3173" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2a166136-d0d0-4493-886b-2dff9f9c3173">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving titanic.csv to titanic.csv

# %%
ti = pd.read_csv('titanic.csv')
ti.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
ti['age'].plot(kind='hist');

# %% [markdown]
# Often pandas doesn't choose the right plot, or the right dataseries... therefore it's often easier to go straight to using seaborn.

# %% [markdown]
# ## How do I use seaborn to visualize data?

# %%
import seaborn as sns

# %% [markdown]
# ### Checks for emptiness and cleanse data

# %%
ti.isna().sum() #check for emptiness
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
#replace NaNs in numerical fields with the mean values
ti=ti.fillna(ti.mean())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.

# %%
# fill every column with its own most frequent value 
ti = ti.apply(lambda x:x.fillna(x.value_counts().index[0]))

# %% [markdown]
# There are two ways of using seaborn, you can either
#
# * supply x (, y, etc.) as individual arguments
# * OR: supply a *dataframe* and name the relevant columns

# %%
sns.distplot(ti['age'], kde=False);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ##### What is the kde?
#
# * approximation of the distribution using a linear combination of normal distributions
#
# * further reading: https://seaborn.pydata.org/tutorial/distributions.html#kernel-density-estimation

# %%
sns.lineplot(ti['age'], ti['fare'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## How do I use a dataframe with seaborn?

# %% [markdown]
# We set `data` to be the dataframe, and *name the columns* for `x` and `y`...

# %%
sns.scatterplot(data=ti, x='age', y='fare')

# %% [markdown]
# ## How do I create a distribution plot?

# %%
sns.distplot(ti['survived'], vertical=True, kde=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## How do I create a violin plot?

# %% [markdown]
# The width of a violin plot is the frequency (ie., how common) a value is within some column...

# %%
sns.violinplot(ti['age'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## How do I create a box plot?

# %% [markdown]
# Box plots show quarties (25th, 50th, 75th) and outliers.

# %%
sns.boxplot(ti['age'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## How do I create a violin plot for multiple columns?

# %% [markdown]
# A violin plot can show multiple distributions, each a subset of a single column, factored (or grouped) by another.

# %%
sns.violinplot(data=ti, x='survived', y='age')

# %%
sns.violinplot(data=ti, x="age", y='embark_town')

# %% [markdown]
# ## How do I create a bar plor for multiple columns?

# %% [markdown]
# Bar plots are useful for discrete data or for showing, here, the means:

# %%
sns.barplot(data=ti, x='survived', y='age');

# %% [markdown]
# ## How do I create a line plot?

# %%
sns.lineplot(data=ti, x='fare', y='age');

# %% [markdown]
# ###### NB: would creating a scatter plot be more appropriate?

# %% [markdown]
# ## How do I create a scatter plot?

# %%
sns.scatterplot(data=ti, x='fare', y='age');

# %%
sns.scatterplot(data=ti, x='fare', y='age', 
                hue = 'sex', 
                size = 'pclass');

# %% [markdown]
# ### EXTRA: Tips
# * Often for the sake of communication, using excel is both faster and leads to better visuals
# * use `df.to_csv()` to save the data behind a visual
# * use excel to heavily customize the layout (and then, eg., copy powerpoint)

# %% [markdown]
# ## Exercise (30 min)
#
# ## Step 1 (5 min)
# * review seaborn individual, try a few plots

# %%
#distplot
sns.distplot(ti['fare'],bins=30,kde=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Jointplot - matchup two distplots for bivariate data.

sns.jointplot(data=ti,x='fare',y='pclass',kind='scatter')

# %%
sns.rugplot(ti['fare'])

# %%
sns.boxplot(data=ti,x='sex',y='fare',palette='coolwarm')

# %%
sns.violinplot(data=ti,x='pclass',y='fare',hue = 'sex',palette='rainbow')

# %%
sns.swarmplot(data=ti,x='pclass',y='fare',hue = 'sex',palette='rainbow')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 36.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 69.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 84.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Step 2 (25 min)
#
# * What affected your chances of survival on the titanic?
#     * brainstorm & execute an analysis of the titanic dataset
# * Consider:
#     * old vs. young
#     * women vs. men
#     * women & children vs. men
#     * cheaper vs. expensive tickets
#     * deck
#     * class
#     * ...location...
# * Use seaborn plots (and pandas) to obtain helpful visuals which answer the investigatory question.

# %%
ti.head(15)
# Out:
#     survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0          0       3    male  22.000000      1      0   7.2500        S
# 1          1       1  female  38.000000      1      0  71.2833        C
# 2          1       3  female  26.000000      0      0   7.9250        S
# 3          1       1  female  35.000000      1      0  53.1000        S
# 4          0       3    male  35.000000      0      0   8.0500        S
# 5          0       3    male  29.699118      0      0   8.4583        Q
# 6          0       1    male  54.000000      0      0  51.8625        S
# 7          0       3    male   2.000000      3      1  21.0750        S
# 8          1       3  female  27.000000      0      2  11.1333        S
# 9          1       2  female  14.000000      1      0  30.0708        C
# 10         1       3  female   4.000000      1      1  16.7000        S
# 11         1       1  female  58.000000      0      0  26.5500        S
# 12         0       3    male  20.000000      0      0   8.0500        S
# 13         0       3    male  39.000000      1      5  31.2750        S
# 14         0       3  female  14.000000      0      0   7.8542        S
#
#      class    who  adult_male deck  embark_town alive  alone
# 0    Third    man        True    C  Southampton    no  False
# 1    First  woman       False    C    Cherbourg   yes  False
# 2    Third  woman       False    C  Southampton   yes   True
# 3    First  woman       False    C  Southampton   yes  False
# 4    Third    man        True    C  Southampton    no   True
# 5    Third    man        True    C   Queenstown    no   True
# 6    First    man        True    E  Southampton    no   True
# 7    Third  child       False    C  Southampton    no  False
# 8    Third  woman       False    C  Southampton   yes  False
# 9   Second  child       False    C    Cherbourg   yes  False
# 10   Third  child       False    G  Southampton   yes  False
# 11   First  woman       False    C  Southampton   yes   True
# 12   Third    man        True    C  Southampton    no   True
# 13   Third    man        True    C  Southampton    no  False
# 14   Third  child       False    C  Southampton    no   True

# %%
#old vs. young
sns.countplot(data=ti,x='adult_male',hue='survived')

# %%
#women vs. men
sns.countplot(data=ti,x='who',hue='survived',order=['man','woman'])    # womens have survived the most

# %%
#women & children vs. men
sns.countplot(data=ti,x='who',hue='survived',order=['child','man']) 

#man have survived more than child

# %%
#cheaper vs. expensive tickets
sns.barplot(data=ti,x='class',y='fare',hue='survived',order=['First','Third']) 

#since first class is greater than third,those who buy expensive tickets have survived more.

# %%
#deck
sns.countplot(data=ti,x='deck',hue='survived')

# persons in the C deck have been survived most.

# %%
#class
sns.countplot(data=ti,x='class',hue='survived')

#the persons who travelled in first class have survived most

# %%
#location
sns.barplot(y='fare',x='embark_town',hue='survived',data=ti)

#the persons who travelled from cherburg has survived most

# %% [markdown]
# ### Consider:
# * Univariate (single-col) plots
#     * sns.distplot
#         * of survived
#     * sns.violinplot
#         * of fare
#     * sns.boxplot
#         * of age

# %% [markdown]
# * Multivariate (here: 2-col) plots
#     * sns.violinplot
#         * age by survived
#         * fare by survived
#     * sns.lineplot
#         * fare vs. age
#     * sns.scatterplot
#         * age vs. fare

# %% [markdown]
# ti[["age","sex"]].groupby(ti.age>18).sum()

# %%
#univariate plots
sns.distplot(ti['survived'], kde=False);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.violinplot(ti['fare'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(ti['age'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#multivariate plots
sns.violinplot(data=ti, x='survived', y='age',palette='Set1')

# %%
sns.violinplot(data=ti, x='survived', y='fare',palette='Set2')

# %%
sns.lineplot(x='fare',y='age',data=ti,palette='coolwarm')

# %%
sns.scatterplot(x='age',y='fare',data=ti,palette='rainbow')

# %%
ti[["age","sex"]].groupby(ti.age>18).sum()
# Out:
#                 age
# age
# False   1489.670000
# True   24972.243824
